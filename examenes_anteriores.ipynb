# %% [markdown]
# # 📘 **Resumen Integrado — Señales y Sistemas (Temas 1, 2 y 3)**
#
# ---
#
# ### 1️⃣ **Serie de Fourier (FS)**
# <details>
# <summary>💡 ¿Qué representa la Serie de Fourier?</summary>
#
# **Respuesta:**
# Una señal periódica continua $x(t)$ puede expresarse como una suma infinita de exponenciales complejas:
#
# $$
# x(t) = \sum_{k=-\infty}^{\infty} a_k e^{jk\omega_0 t}
# $$
#
# donde los coeficientes se calculan como:
#
# $$
# a_k = \frac{1}{T_0}\int_{T_0} x(t)e^{-jk\omega_0 t}\,dt
# $$
#
# ---
#
# **Teoría breve:**
# Cada término $a_k e^{jk\omega_0 t}$ representa un **armónico** con frecuencia $k\omega_0$.
# La serie de Fourier permite analizar una señal en función de sus **componentes de frecuencia**.
#
# **Conceptos previos necesarios:**
# - Periodicidad (Tema 1)
# - Señales senoidales
# - Propiedades de simetría (par/impar)
#
# </details>
#
# ---
#
# ### 2️⃣ **DTFS (Serie de Fourier en Tiempo Discreto)**
# <details>
# <summary>💡 ¿Cómo se expresa una señal periódica discreta en frecuencia?</summary>
#
# **Respuesta:**
# $$
# x[n] = \sum_{k=0}^{N_0-1} a_k e^{j\frac{2\pi}{N_0}kn}
# $$
#
# con coeficientes:
# $$
# a_k = \frac{1}{N_0}\sum_{n=0}^{N_0-1}x[n] e^{-j\frac{2\pi}{N_0}kn}
# $$
#
# ---
#
# **Teoría breve:**
# - Es la versión discreta de la Serie de Fourier.
# - Describe señales periódicas **discretas** con $N_0$ muestras por período.
# - Si la señal no es periódica, se usa la **DTFT** o la **DFT**.
#
# **Conexión:**
# Aplica conceptos del **muestreo (Tema 1)** y de **sistemas LTI (Tema 2)**.
#
# </details>
#
# ---
#
# ### 3️⃣ **Transformada de Fourier (FT)**
# <details>
# <summary>💡 ¿Qué representa la Transformada de Fourier?</summary>
#
# **Respuesta:**
# $$
# X(j\omega)=\int_{-\infty}^{\infty}x(t)e^{-j\omega t}dt
# $$
#
# y su inversa:
# $$
# x(t)=\frac{1}{2\pi}\int_{-\infty}^{\infty}X(j\omega)e^{j\omega t}d\omega
# $$
#
# ---
#
# **Teoría breve:**
# Convierte una señal **no periódica** del dominio del tiempo al dominio de la **frecuencia**.
# Permite ver **qué frecuencias componen la señal** y con qué amplitud.
#
# **Relación clave:**
# $$
# y(t)=x(t)*h(t) \;\Longleftrightarrow\; Y(j\omega)=X(j\omega)H(j\omega)
# $$
#
# **Conceptos previos:**
# Integrales, convolución y sistemas LTI.
#
# </details>
#
# ---
#
# ### 4️⃣ **Sistemas LTI y Convolución**
# <details>
# <summary>💡 ¿Cómo se calcula la salida de un sistema LTI?</summary>
#
# **Respuesta:**
# - En continuo:
# $$
# y(t)=\int_{-\infty}^{\infty}x(\tau)h(t-\tau)d\tau
# $$
# - En discreto:
# $$
# y[n]=\sum_{k=-\infty}^{\infty}x[k]h[n-k]
# $$
#
# ---
#
# **Teoría breve:**
# Cada muestra de $x[k]$ **activa una copia desplazada** de $h[n]$.
# La salida $y[n]$ es la **suma ponderada** de todas esas respuestas.
# Esto se conoce como **convolución discreta**.
#
# **Propiedades importantes:**
# - Conmutativa → $x*h = h*x$
# - Asociativa → $(x*h_1)*h_2 = x*(h_1*h_2)$
# - Distributiva → $x*(h_1+h_2)=x*h_1+x*h_2$
#
# </details>
#
# ---
#
# ### 5️⃣ **Relación tiempo ↔ frecuencia**
# <details>
# <summary>💡 ¿Qué relación existe entre tiempo y frecuencia?</summary>
#
# **Respuesta:**
# $$
# y(t)=x(t)*h(t) \;\Longleftrightarrow\; Y(j\omega)=X(j\omega)H(j\omega)
# $$
#
# ---
#
# **Teoría breve:**
# - El dominio del tiempo muestra **cómo varía la señal**.
# - El dominio de la frecuencia muestra **qué contiene la señal**.
# - La convolución en tiempo se convierte en un **producto en frecuencia**.
#
# **Propiedades espectrales:**
# | Propiedad | Efecto |
# |:--|:--|
# | Linealidad | Suma de señales → suma de espectros |
# | Desplazamiento temporal | Multiplica el espectro por $e^{-j\omega t_0}$ |
# | Escalado | Comprime o estira el espectro |
# | Convolución ↔ Producto | Convolución en tiempo = producto en frecuencia |
#
# </details>
#
# ---
#
# ### 6️⃣ **Muestreo y aliasing**
# <details>
# <summary>💡 ¿Qué es el muestreo y cómo se evita el aliasing?</summary>
#
# **Respuesta:**
# El muestreo consiste en tomar muestras de una señal continua cada $T_s$ segundos:
# $$
# x[n]=x(t)|_{t=nT_s}
# $$
# La frecuencia de muestreo es:
# $$
# f_s=\frac{1}{T_s}
# $$
#
# Para evitar **aliasing**, se debe cumplir el **Teorema de Nyquist**:
# $$
# f_s > 2f_{max}
# $$
#
# ---
#
# **Teoría breve:**
# El aliasing ocurre cuando las copias del espectro se superponen.
# Si $f_s$ es demasiado bajo, las frecuencias se mezclan y la señal original no puede recuperarse.
#
# **Conceptos previos:**
# Señales continuas (Tema 1), espectro (Tema 3).
#
# </details>
#
# ---
#
# ### 7️⃣ **Energía y Potencia de señales**
# <details>
# <summary>💡 ¿Cómo se clasifican las señales según su energía o potencia?</summary>
#
# **Respuesta:**
# | Tipo | Definición | Ejemplo |
# |:--|:--|:--|
# | Energía | $E_x=\int |x(t)|^2 dt < \infty$ | $x(t)=e^{-t}u(t)$ |
# | Potencia | $P_x=\lim_{T\to\infty}\frac{1}{2T}\int_{-T}^{T}|x(t)|^2dt$ | $x(t)=A\cos(\omega t)$ |
#
# ---
#
# **Teoría breve:**
# Las señales **de energía** tienen duración finita o decaen a cero.
# Las **de potencia** son periódicas (no decaen).
#
# **Teorema de Parseval:**
# $$
# E_x=\int |X(j\omega)|^2 d\omega
# $$
#
# </details>
#
# ---
#
# ### 8️⃣ **Conexión general entre temas**
# <details>
# <summary>💡 ¿Cómo se relacionan los temas 1, 2 y 3?</summary>
#
# | Tema | Concepto | Conecta con |
# |:--|:--|:--|
# | 1 | Tipos de señales, energía/potencia, simetría | Base para periodicidad y clasificación |
# | 2 | Sistemas LTI y convolución | Describe cómo las señales se procesan |
# | 3 | Fourier (FS, DTFS, FT) | Analiza las señales en frecuencia |
# | – | Muestreo | Une continuo ↔ discreto |
# | – | Espectro | Explica el dominio de frecuencia |
#
# ---
#
# **Teoría breve:**
# - Una señal puede verse en tiempo o en frecuencia.
# - Un sistema LTI transforma la señal según su respuesta al impulso.
# - La **Transformada de Fourier** describe esa transformación en frecuencia.
# - El **muestreo** conecta los dos mundos (continuo y discreto).
#
# </details>
#
# ---

# %% [markdown]
# ## Examen 1 - Señales y Sistemas (Teoría 2023)
#
# ---
#
# <details>
# <summary>📘 Problema 1 — Propiedades de un sistema continuo</summary>
#
# **Enunciado**
# Sea el sistema de tiempo continuo definido por:
# $$
# y(t)=\int_{t-T}^{t}x(\tau)\,d\tau, \quad T>0
# $$
#
# Analizar si el sistema presenta las propiedades de **estabilidad**, **invarianza temporal** y **causalidad**.
#
# ---
#
# ### 1️⃣ Estabilidad
# Si la entrada está acotada, $|x(t)|\le B$, se cumple:
# $$
# |y(t)|=\left|\int_{t-T}^{t}x(\tau)\,d\tau\right|
# \le \int_{t-T}^{t}|x(\tau)|\,d\tau
# \le B\int_{t-T}^{t}d\tau = BT < \infty
# $$
# El sistema **no amplifica indefinidamente** las señales acotadas.
#
# **Conclusión:** **BIBO estable** (Bounded Input → Bounded Output).
#
# ---
#
# ### 2️⃣ Invarianza en el tiempo
# Si se desplaza la entrada:
# $$
# x'(t)=x(t-t_0)
# \Rightarrow
# y'(t)=\int_{t-T}^{t}x(\tau-t_0)\,d\tau
# =\int_{t-T-t_0}^{t-t_0}x(\sigma)\,d\sigma
# = y(t-t_0)
# $$
#
# **Conclusión:** el sistema **es invariante**.
# El comportamiento no cambia en el tiempo: un desplazamiento en la entrada produce el mismo desplazamiento en la salida.
#
# ---
#
# ### 3️⃣ Causalidad
# Para $x(t)=\delta(t)$,
# $$
# h(t)=\int_{t-T}^{t}\delta(\tau)\,d\tau=u(t)-u(t-T)
# $$
# Como $h(t)=0$ para $t<0$, la salida solo depende de valores **pasados o presentes** de la entrada.
#
# **Conclusión:** el sistema es **causal**.
#
# ---
#
# ### 🧠 Teoría
# Este sistema **integra la señal de entrada en una ventana finita** de duración $T$.
# - Actúa como un **promediador móvil**: la salida en cada instante $t$ representa la energía promedio de la señal en el intervalo $[t-T,\,t]$.
# - Es **LTI** (lineal e invariante en el tiempo) porque cumple ambas propiedades y su respuesta impulsional es fija.
# - Este tipo de sistema suaviza la señal, reduciendo ruido o variaciones rápidas (similar a un filtro paso bajo en frecuencia).
#
# ---
#
# </details>
#
# ---
#
# <details>
# <summary>📗 Problema 2 — Serie de Fourier Discreta (DTFS)</summary>
#
# **Enunciado**
# Dada la señal periódica discreta:
# $$
# x[n]=1+e^{j\pi n/3}+\tfrac12\sin\!\left(\tfrac{\pi n}{2}\right)+\cos\!\left(\tfrac{3\pi n}{9}\right)
# $$
# calcular:
# 1. El **periodo fundamental** $N_0$ y la **pulsación fundamental** $\omega_0$.
# 2. Los **coeficientes $a_k$** del desarrollo en serie de Fourier discreta (DTFS).
# 3. El efecto de **inversión y desplazamiento temporal** en el espectro.
#
# ---
#
# ### 1️⃣ Periodo y pulsación fundamentales
#
# Frecuencias parciales:
# - $\omega_1=\pi/3 \Rightarrow N_1=6$
# - $\omega_2=\pi/2 \Rightarrow N_2=4$
# - $\omega_3=\pi/3 \Rightarrow N_3=6$
#
# $$
# N_0=\mathrm{mcm}(6,4,6)=12, \qquad
# \omega_0=\frac{2\pi}{N_0}=\frac{\pi}{6}
# $$
#
# **Conclusión:** la señal es periódica con periodo $N_0=12$.
#
# ---
#
# ### 2️⃣ Coeficientes del DTFS
#
# Expresando en exponenciales:
# $$
# x[n]=1+e^{j(2\pi n/6)}+\tfrac12\frac{e^{j(3\pi n/6)}-e^{-j(3\pi n/6)}}{2j}
# +\frac{e^{j(2\pi n/6)}+e^{-j(2\pi n/6)}}{2}
# $$
#
# Coeficientes no nulos:
# $$
# a_0=1,\quad a_2=\tfrac12,\quad a_3=-\tfrac{j}{4},\quad
# a_{-2}=\tfrac32,\quad a_{-3}=\tfrac{j}{4}.
# $$
#
# ---
#
# ### 3️⃣ Efecto de desplazamiento e inversión
#
# Si $y[n]=x[-n-2]$, se aplican propiedades:
# - **Desplazamiento:** $x[n-n_0]\leftrightarrow a_k e^{-jk\omega_0 n_0}$
# - **Inversión:** $x[-n]\leftrightarrow a_{-k}$
#
# Combinando:
# $$
# b_k=a_{-k}e^{j2k\pi/6}=a_{-k}e^{jk\pi/3}.
# $$
#
# ---
#
# ### 🧠 Teoría
# Este problema une los conceptos del **Tema 3 (Series de Fourier)**:
# - El DTFS representa una señal periódica discreta como suma de **exponenciales complejas**:
#   $$
#   x[n]=\sum_{k=0}^{N_0-1} a_k e^{jk\omega_0 n}.
#   $$
# - Cada $a_k$ mide la **energía y fase** de la componente armónica $k$.
# - El **desplazamiento temporal** produce una **rotación de fase lineal** en frecuencia.
# - La **inversión temporal** refleja el espectro en torno al eje $k=0$.
#
# En la práctica, estas propiedades son la base de los **filtros digitales** y de la **transformada de Fourier discreta (DFT)** usada en MATLAB.
#
# ---
#
# </details>
#
# ---
#
# <details>
# <summary>📕 Problema 3 — Sistemas discretos LTI y convolución</summary>
#
# **Enunciado**
# Se define un sistema LTI de tiempo discreto mediante:
# $$
# y[n]+y[n-2]=x[n]+x[n-1]+2x[n-2].
# $$
#
# Se pide:
# 1. Calcular la **respuesta al impulso** $h_1[n]$.
# 2. Calcular la **salida ante un pulso rectangular** $x[n]=u[n+1]-u[n-2]$.
# 3. Calcular la **salida total** si el sistema se conecta en paralelo con otro $h_2[n]=2\delta[n]$.
#
# ---
#
# ### 1️⃣ Respuesta al impulso
#
# Con $x[n]=\delta[n]$:
# $$
# \begin{aligned}
# h[0]&=1,\\
# h[1]&=1,\\
# h[2]&=3,\\
# h[3]&=1,\\
# h[4]&=3,\ \ldots
# \end{aligned}
# $$
# Expresión general:
# $$
# h_1[n]=\delta[n]+2u[n-1]+(-1)^n u[n-1].
# $$
#
# ---
#
# ### 2️⃣ Salida ante un pulso rectangular
#
# Entrada:
# $$
# x[n]=u[n+1]-u[n-2].
# $$
# Salida (convolución):
# $$
# y_1[n]=x[n]*h_1[n].
# $$
# Gráficamente, la salida equivale a la **suma de tres copias desplazadas** de $h_1[n]$.
# Expresión dada:
# $$
# y_1[n]=\delta[n-1]+2\delta[n]+5\delta[n-1]+6u[n-2]+(-1)^{n+1}u[n-2].
# $$
#
# ---
#
# ### 3️⃣ Conexión en paralelo
#
# $$
# y[n]=y_1[n]+2x[n]
# =3\delta[n-1]+4\delta[n]+5u[n-1]+(-1)^{n+1}u[n-1].
# $$
#
# ---
#
# ### 🧠 Teoría
# Este bloque corresponde al **Tema 2 (Sistemas LTI)**:
# - La respuesta del sistema LTI se obtiene mediante **convolución discreta**:
#   $$
#   y[n]=x[n]*h[n]=\sum_k x[k]h[n-k].
#   $$
# - La convolución **suma los efectos** de la respuesta impulsional ante cada muestra de entrada.
# - La **causalidad** se observa cuando $h[n]=0$ para $n<0$.
# - La **estabilidad BIBO** se garantiza si $\sum |h[n]|<\infty$.
# - Las **interconexiones** (serie o paralelo) permiten combinar sistemas LTI sumando o convolucionando sus respuestas.
#
# En este examen, el sistema muestra un **comportamiento oscilatorio** típico de sistemas recursivos (IIR), y la suma en paralelo con $2\delta[n]$ actúa como una **realimentación inmediata**, amplificando la salida.
#
# ---
#
# </details>
#
# ---
#
# ### 🧩 Resumen conceptual
#
# | Tema | Concepto clave | Ejemplo del examen |
# |------|----------------|--------------------|
# | **1** | Señales continuas, convolución e impulso | Integrador finito \(y(t)=\int x(\tau)d\tau\) |
# | **2** | Sistemas LTI, causalidad, estabilidad | Ecuación en diferencias y convolución discreta |
# | **3** | Series de Fourier (DTFS) | Descomposición armónica de señales periódicas |
#
# ---
#
# **Conclusión general:**
# El examen combina los tres pilares del curso:
# 1️⃣ *Modelado de sistemas LTI en tiempo continuo y discreto.*
# 2️⃣ *Respuesta temporal mediante convolución.*
# 3️⃣ *Análisis espectral mediante Series de Fourier.*
# Estos principios forman la base del tratamiento digital de señales (filtrado, muestreo y análisis en frecuencia).
#
# ---

# %% [markdown]
# ## Problema 1 (3 puntos) — Sistema DT con ventana finita y factor cosenoidal
#
# Sea el sistema de tiempo discreto:
# $$
# y[n]=\frac{1}{N+1}\sum_{k=n-N}^{n} x[k]\;\cos\!\left(\frac{\pi n}{2}\right),
# \qquad N\in\mathbb{Z}^+,\; N\ge 2.
# $$
#
# Se pide analizar: **(a)** causalidad, **(b)** estabilidad BIBO, **(c)** linealidad (aditividad y homogeneidad), **(d)** invariancia temporal; y **(2)** obtener la respuesta al impulso \(h[n]\) y representarla para \(N=3\).
#
# ---
#
# <details>
# <summary>1.a) Causalidad</summary>
#
# **Análisis.**
# Para un índice fijo \(n_0\),
# $$
# y[n_0]=\frac{1}{N+1}\sum_{k=n_0-N}^{n_0} x[k]\;\cos\!\left(\frac{\pi n_0}{2}\right).
# $$
# La suma usa únicamente valores de \(x[k]\) con \(k\le n_0\) (pasado y presente).
#
# **Conclusión.** El sistema es **causal**.
# </details>
#
# ---
#
# <details>
# <summary>1.b) Estabilidad BIBO</summary>
#
# **Hipótesis.** Si \(|x[n]|\le B\) para todo \(n\), entonces
# $$
# |y[n]|
# \le \frac{1}{N+1}\sum_{k=n-N}^{n} |x[k]|\; \bigl|\cos\!\left(\tfrac{\pi n}{2}\right)\bigr|
# \le \frac{1}{N+1}\sum_{k=n-N}^{n} B
# = B.
# $$
#
# **Conclusión.** Toda entrada acotada produce salida acotada: **BIBO estable**.
# </details>
#
# ---
#
# <details>
# <summary>1.c) Linealidad (aditividad y homogeneidad)</summary>
#
# **Aditividad.** Para \(x[n]=x_1[n]+x_2[n]\),
# $$
# y[n]=\frac{1}{N+1}\sum_{k=n-N}^{n} \bigl(x_1[k]+x_2[k]\bigr)\cos\!\left(\tfrac{\pi n}{2}\right)
# = y_1[n]+y_2[n].
# $$
#
# **Homogeneidad.** Para \(x'[n]=\alpha x[n]\),
# $$
# y'[n]=\frac{1}{N+1}\sum_{k=n-N}^{n} \alpha x[k]\cos\!\left(\tfrac{\pi n}{2}\right)=\alpha\,y[n].
# $$
#
# **Conclusión.** El sistema es **lineal**.
# </details>
#
# ---
#
# <details>
# <summary>1.d) Invariancia temporal</summary>
#
# **Prueba.** Con \(x'(n)=x[n-n_0]\),
# $$
# y'[n]=\frac{1}{N+1}\sum_{k=n-N}^{n} x[k-n_0]\cos\!\left(\tfrac{\pi n}{2}\right).
# $$
# En cambio,
# $$
# y[n-n_0]=\frac{1}{N+1}\sum_{k=n-n_0-N}^{n-n_0} x[k]\;\underbrace{\cos\!\left(\tfrac{\pi (n-n_0)}{2}\right)}_{\neq \cos(\pi n/2)\, \text{en general}}.
# $$
# El factor \(\cos(\tfrac{\pi n}{2})\) **depende explícitamente de \(n\)**, por lo que, en general, \(y'[n]\ne y[n-n_0]\).
#
# **Conclusión.** **No invariante en el tiempo** (no TI).
# </details>
#
# ---
#
# <details>
# <summary>2) Respuesta al impulso \(h[n]\) y caso \(N=3\)</summary>
#
# **Definición.** Para \(x[n]=\delta[n]\),
# $$
# h[n]=\frac{1}{N+1}\sum_{k=n-N}^{n}\delta[k]\;\cos\!\left(\tfrac{\pi n}{2}\right)
# =\frac{1}{N+1}\cos\!\left(\tfrac{\pi n}{2}\right)\,\bigl(u[n]-u[n-N-1]\bigr).
# $$
#
# **Particularización \(N=3\).**
# $$
# h[n]=\frac{1}{4}\cos\!\left(\tfrac{\pi n}{2}\right)\,\bigl(u[n]-u[n-4]\bigr),
# $$
# de modo que
# \[
# h[0]=\tfrac14,\quad
# h[1]=0,\quad
# h[2]=-\tfrac14,\quad
# h[3]=0,\quad
# h[n]=0\ \text{si}\ n<0\ \text{o}\ n\ge 4.
# \]
#
# **Descripción gráfica (N=3).** Secuencia finita de longitud 4 con muestras:
# \((n,h[n])=\{(0,\tfrac14),\ (1,0),\ (2,-\tfrac14),\ (3,0)\}\).
# </details>
#
# ---
#
# ### Teoría (conexiones y lectura rápida)
# - El sistema **promedia** \(N\!+\!1\) muestras pasadas y presentes de \(x[k]\) (ventana rectangular) y las **modula** por \(\cos(\pi n/2)\), que depende del tiempo \(n\).
# - Es **lineal** y **causal**; es **BIBO estable** porque la suma promediada no puede exceder el máximo de la entrada.
# - **No es TI** (no LTI) porque el multiplicador \(\cos(\pi n/2)\) varía con \(n\): un simple desplazamiento de la entrada no produce un mero desplazamiento de la salida.
# - La respuesta al impulso \(h[n]\) es un **pulso finito** (ventana de longitud \(N\!+\!1\)) ponderado por una **portadora discreta** \(\cos(\pi n/2)\), lo que alterna signos y ceros según \(n\).
#
# ---

# %% [markdown]
# ## Problema 2 (3 puntos) — Convolución en tiempo continuo e invarianza temporal
#
# Se da la **respuesta al impulso** de un sistema LTI continuo:
# $$
# h(t) = u(-t + 1) - u(-t - 1)
# $$
# y la **entrada:**
# $$
# x(t) = 2u(t + 2) - 2u(t - 3)
# $$
#
# ---
#
# <details>
# <summary>📘 2.1) Representación de \(x(t)\) y \(h(t)\)</summary>
#
# **Entrada \(x(t)\):**
# \[
# x(t) =
# \begin{cases}
# 2, & -2 \le t < 3 \\
# 0, & \text{en otro caso}
# \end{cases}
# \]
#
# → Rectángulo de altura 2 y base 5 (soporte en \([-2,3]\)).
#
# **Respuesta impulsional \(h(t)\):**
# \[
# h(t) =
# \begin{cases}
# 1, & -1 < t < 1 \\
# 0, & \text{en otro caso}
# \end{cases}
# \]
#
# → Rectángulo de altura 1 y base 2 (soporte en \([-1,1]\)).
#
# </details>
#
# ---
#
# <details>
# <summary>📗 2.2) Cálculo y representación de la convolución \(y(t) = x(t) * h(t)\)</summary>
#
# La convolución es:
# \[
# y(t) = \int_{-\infty}^{\infty} x(\tau)\,h(t - \tau)\,d\tau
# \]
#
# Ambas señales son rectángulos ⇒ \(y(t)\) será una función **triangular trapezoidal** (resultado del solapamiento entre \(x(t)\) y \(h(t)\)).
#
# ---
#
# ### Por tramos:
#
# 1️⃣ **Sin solape:** \(t < -3 \Rightarrow y(t) = 0.\)
#
# 2️⃣ **Inicio del solape:** \(-3 < t < -1\)
# \[
# y(t) = \int_{-2}^{t+1} 2\,d\tau = 2(t + 1) - 2(-2) = 2t + 6
# \]
#
# 3️⃣ **Solape completo:** \(-1 \le t \le 2\)
# \[
# y(t) = \int_{t - 1}^{t + 1} 2\,d\tau = 4
# \]
#
# 4️⃣ **Final del solape:** \(2 < t < 4\)
# \[
# y(t) = \int_{t - 1}^{3} 2\,d\tau = 2(3 - (t - 1)) = 8 - 2t
# \]
#
# 5️⃣ **Sin solape:** \(t > 4 \Rightarrow y(t) = 0.\)
#
# ---
#
# ### Resultado final:
# \[
# y(t) =
# \begin{cases}
# 0, & t \le -3, \\[2mm]
# 2t + 6, & -3 < t < -1, \\[2mm]
# 4, & -1 \le t \le 2, \\[2mm]
# 8 - 2t, & 2 < t < 4, \\[2mm]
# 0, & t \ge 4.
# \end{cases}
# \]
#
# ---
#
# **Gráfica:**
# Triángulo isósceles centrado aproximadamente en \(t \in [-3, 4]\) con altura 4.
#
# </details>
#
# ---
#
# <details>
# <summary>📗 2.3) Forma alternativa dada</summary>
#
# El enunciado también permite usar la forma simplificada:
# \[
# y(t) =
# \begin{cases}
# 4 + t, & -4 < t \le 0, \\[1mm]
# 4 - t, & 0 < t < 4, \\[1mm]
# 0, & \text{resto.}
# \end{cases}
# \]
#
# Ambas expresiones son equivalentes (representan una forma **triangular simétrica**, desplazada o no en el eje temporal).
#
# </details>
#
# ---
#
# <details>
# <summary>📘 2.4) Demostración de invarianza temporal</summary>
#
# Sea \(x'(t) = x(t - t_0)\).
# El sistema responde con:
# \[
# y'(t) = x'(t) * h(t)
# = \int_{-\infty}^{\infty} h(\tau)\,x(t - t_0 - \tau)\,d\tau
# = y(t - t_0)
# \]
# **Conclusión:**
# Un desplazamiento temporal en la entrada produce el **mismo desplazamiento** en la salida.
# El sistema es **invariante en el tiempo** (TI).
#
# </details>
#
# ---
#
# <details>
# <summary>📘 2.5) Superposición lineal — Entrada combinada</summary>
#
# Se define una nueva señal:
# \[
# x'(t) = x(t) + \frac{1}{2}x(t - 4) + x(t + 4)
# \]
#
# Por **linealidad** e **invarianza temporal**:
# \[
# y'(t) = y(t) + \frac{1}{2}y(t - 4) + y(t + 4)
# \]
#
# La salida total \(y'(t)\) se obtiene como la **suma de tres triángulos**:
# - Uno centrado en \(t = 0\) (original).
# - Uno desplazado \(+4\) (ponderado por \(1/2\)).
# - Uno desplazado \(-4\) (ponderado por 1).
#
# **Representación:**
# La superposición genera una función continua compuesta por tres triángulos desplazados y sumados.
#
# </details>
#
# ---
#
# ### 🧠 Teoría y conexiones conceptuales
#
# **1️⃣ Convolución en tiempo continuo**
# - La operación \(y(t) = x(t) * h(t)\) mide el **grado de solapamiento** entre la entrada \(x\) y una copia invertida de \(h\).
# - Si \(x(t)\) y \(h(t)\) son rectángulos, su convolución es **triangular**.
# - Es una operación **lineal** (superposición válida) y **conmutativa** (\(x*h = h*x\)).
#
# **2️⃣ Invarianza temporal**
# - En sistemas LTI, desplazar la entrada equivale a desplazar la salida:
#   \[
#   x(t - t_0) \Rightarrow y(t - t_0).
#   \]
# - Esta propiedad es esencial para el análisis con transformadas de Fourier.
#
# **3️⃣ Interpretación física**
# - El sistema “promedia” el valor de \(x(t)\) dentro del intervalo en el que \(h(t)\) es distinto de cero.
# - Si \(h(t)\) es un **rectángulo centrado en 0**, el sistema actúa como un **filtro paso bajo idealizado** (suaviza la señal).
# - La suma ponderada \(y'(t) = y(t) + \tfrac{1}{2}y(t - 4) + y(t + 4)\) representa la **superposición de respuestas** por entradas desplazadas (propiedad de superposición lineal).
#
# **4️⃣ Conexión con el temario**
# - **Tema 1:** señales y funciones impulso.
# - **Tema 2:** convolución continua y propiedades de sistemas LTI.
# - **Tema 3:** relación con transformadas y representación espectral de \(h(t)\).
#
# ---
#
# **Conclusión general:**
# El sistema es **lineal, invariante y causal**, con respuesta triangular típica de un filtro integrador rectangular.
# Este tipo de análisis se usa para caracterizar **filtros promediadores** y **respuestas temporales equivalentes** en sistemas físicos.
#
# ---

# %% [markdown]
# ## Problema 3 (2 puntos) — Análisis de un sistema LTI discreto con ecuación en diferencias
#
# Se considera un sistema lineal e invariante en el tiempo (LTI) discreto definido por:
# $$
# y[n] + y[n-2] = x[n] + x[n-1] + 2x[n-2]
# $$
#
# Se pide:
#
# 1️⃣ Obtener la **respuesta al impulso** \(h_1[n]\).
# 2️⃣ Calcular la **salida** ante \(x[n] = u[n+1] - u[n-2]\).
# 3️⃣ Determinar la **salida total** si el sistema se conecta en **paralelo** con otro cuya respuesta es \(h_2[n] = 2\delta[n]\).
#
# ---
#
# <details>
# <summary>📘 3.1) Respuesta al impulso del sistema \(h_1[n]\)</summary>
#
# **Planteamiento:**
# Para encontrar la respuesta impulsional \(h_1[n]\), se aplica una entrada \(x[n] = \delta[n]\) y se supone el sistema **causal**, es decir:
# \[
# y[n] = 0 \quad \text{para } n < 0.
# \]
#
# De la ecuación del sistema:
# \[
# y[n] = x[n] + x[n-1] + 2x[n-2] - y[n-2].
# \]
#
# ---
#
# **Cálculo iterativo:**
# \[
# \begin{aligned}
# y[0] &= 1,\\
# y[1] &= 1,\\
# y[2] &= 3,\\
# y[3] &= 1,\\
# y[4] &= 3,\\
# \ldots
# \end{aligned}
# \]
#
# Por tanto, la secuencia se repite alternando valores 1 y 3.
# La forma general que resume este comportamiento (según la resolución del examen) es:
# \[
# \boxed{h_1[n] = \delta[n] + 2u[n-1] + (-1)^n u[n-1]}
# \]
#
# **Interpretación:**
# - Es una secuencia **causal** (empieza en \(n = 0\)).
# - La parte \(2u[n-1]\) produce un crecimiento constante.
# - El término \((-1)^n u[n-1]\) genera una **oscilación alternante** (1, -1, 1, -1, …).
#
# ---
#
# </details>
#
# ---
#
# <details>
# <summary>📗 3.2) Salida ante un pulso rectangular</summary>
#
# **Entrada:**
# \[
# x[n] = u[n+1] - u[n-2]
# \]
# → Pulso rectangular de duración 3 muestras y amplitud 1 (activa en \(n = -1, 0, 1\)).
#
# ---
#
# **Convolución:**
# \[
# y_1[n] = x[n] * h_1[n] = \sum_{k=-\infty}^{\infty} x[k]\,h_1[n - k].
# \]
#
# Como la entrada es finita, basta con sumar tres copias desplazadas de \(h_1[n]\) en \(n = -1, 0, 1\).
#
# ---
#
# **Expresión (según la resolución del examen):**
# \[
# \boxed{
# y_1[n] = \delta[n-1] + 2\delta[n] + 5\delta[n-1] + 6u[n-2] + (-1)^{n+1}u[n-2]
# }
# \]
#
# **Interpretación:**
# - Se observa una **combinación de respuestas impulsionales desplazadas**.
# - La parte de escalones \(6u[n-2]\) representa la acumulación de valores constantes.
# - El término \((-1)^{n+1}u[n-2]\) refleja el efecto oscilatorio propio de \(h_1[n]\).
#
# ---
#
# </details>
#
# ---
#
# <details>
# <summary>📘 3.3) Conexión en paralelo con \(h_2[n] = 2\delta[n]\)</summary>
#
# **Propiedad de sistemas en paralelo:**
# \[
# y[n] = y_1[n] + y_2[n] = y_1[n] + (x * h_2)[n] = y_1[n] + 2x[n].
# \]
#
# Sustituyendo:
# \[
# \boxed{
# y[n] = 3\delta[n-1] + 4\delta[n] + 5u[n-1] + (-1)^{n+1}u[n-1]
# }
# \]
#
# ---
#
# **Interpretación:**
# - La conexión **paralela** suma las salidas de ambos sistemas.
# - El término \(2x[n]\) actúa como una **ganancia directa** aplicada a la entrada.
# - El resultado conserva la estructura del sistema base, pero amplifica la respuesta inicial.
#
# ---
#
# </details>
#
# ---
#
# ### 🧠 Teoría y conexiones conceptuales
#
# **1️⃣ Ecuaciones en diferencias**
# - Definen relaciones **recursivas** entre las muestras de entrada y salida.
# - La existencia de términos como \(y[n-2]\) indica que el sistema tiene **memoria** (respuesta depende de salidas pasadas).
# - La resolución puede obtenerse:
#   - Iterativamente (como en el examen).
#   - Mediante **Transformada Z**, que simplifica el análisis algebraico.
#
# ---
#
# **2️⃣ Respuesta impulsional**
# - La **respuesta al impulso** \(h[n]\) caracteriza completamente un sistema LTI:
#   \[
#   y[n] = (x * h)[n].
#   \]
# - Si \(h[n]\) es finita → sistema de **duración finita** (FIR).
# - Si es infinita (como en sistemas recursivos) → sistema **IIR**.
#
# ---
#
# **3️⃣ Convolución discreta**
# - Define cómo el sistema combina valores pasados de la entrada para generar la salida:
#   \[
#   y[n] = \sum_k x[k]\,h[n - k].
#   \]
# - Es **lineal y conmutativa**, propiedades clave de los sistemas LTI.
#
# ---
#
# **4️⃣ Estabilidad y causalidad**
# - **Causalidad:** \(h[n] = 0\) para \(n < 0\).
# - **Estabilidad BIBO:** se cumple si
#   \[
#   \sum_n |h[n]| < \infty.
#   \]
#   En este sistema, la oscilación \((-1)^n\) está acotada y el término \(u[n]\) limitado, por tanto es **estable**.
#
# ---
#
# **5️⃣ Conexiones entre sistemas**
# - **Paralelo:** \(h_{eq}[n] = h_1[n] + h_2[n]\).
# - **Serie:** \(h_{eq}[n] = h_1[n] * h_2[n]\).
# - **Realimentación:** modifica la estabilidad y puede introducir resonancia.
#
# ---
#
# **6️⃣ Conexión con el temario**
# - **Tema 1:** señales discretas, deltas y escalones.
# - **Tema 2:** sistemas LTI, ecuaciones en diferencias, estabilidad.
# - **Tema 3:** relación con transformadas y análisis espectral.
#
# ---
#
# **Conclusión general:**
# Este problema combina todos los fundamentos de los **sistemas discretos LTI**:
# - La respuesta impulsional \(h_1[n]\) describe el comportamiento básico.
# - La salida ante señales compuestas se obtiene mediante **convolución**.
# - Las conexiones en paralelo muestran cómo los sistemas se combinan linealmente.
#
# Estos conceptos son esenciales para el diseño de **filtros digitales (FIR/IIR)**, la implementación en MATLAB y el análisis temporal y frecuencial en procesamiento de señales.
#
# ---

# %% [markdown]
# ## Examen 1 - Señales y Sistemas (Teoría 2023)
#
# ---
#
# <details>
# <summary>📘 Problema 1.1 — Propiedades del sistema continuo</summary>
#
# **Enunciado:**
# Sea el sistema de tiempo continuo definido por
# $$
# y(t) = \int_{t-T}^{t} x(\tau)\, d\tau, \quad T \in \mathbb{R}^+, \; T < \infty
# $$
#
# Analizar si el sistema presenta las siguientes propiedades: **estabilidad**, **invarianza en el tiempo** y **causalidad**.
#
# ---
#
# ### **1. Estabilidad**
#
# Si la entrada está acotada:
# $$|x(t)| \le B, \ \forall t \in \mathbb{R}$$
# entonces:
# $$
# |y(t)| = \left|\int_{t-T}^{t} x(\tau)\, d\tau \right|
# \le \int_{t-T}^{t} |x(\tau)|\, d\tau
# \le B \int_{t-T}^{t} d\tau = BT < \infty
# $$
#
# **Conclusión:** el sistema es **BIBO estable**.
#
# ---
#
# ### **2. Invarianza en el tiempo**
#
# Sea una entrada desplazada \( x'(t) = x(t - t_0) \).
# Entonces la salida será:
# $$
# y'(t) = \int_{t-T}^{t} x'(\tau)\, d\tau =
# \int_{t-T}^{t} x(\tau - t_0)\, d\tau
# $$
# haciendo el cambio de variable \( \sigma = \tau - t_0 \):
# $$
# y'(t) = \int_{t-T-t_0}^{t-t_0} x(\sigma)\, d\sigma
# = y(t - t_0)
# $$
#
# **Conclusión:** el sistema es **invariante en el tiempo**.
#
# ---
#
# ### **3. Causalidad**
#
# Sea la entrada impulso \( x(t) = \delta(t) \).
# Entonces la respuesta impulsional es:
# $$
# h(t) = \int_{t-T}^{t} \delta(\tau)\, d\tau
# = u(t) - u(t - T)
# $$
#
# Como \( h(t) = 0, \forall t < 0 \), el sistema **es causal**.
#
# ---
#
# **Teoría:**
# Un sistema continuo \( y(t) = \int_{t-T}^{t} x(\tau)\, d\tau \) actúa como un **integrador finito (ventana de duración T)**.
# Es **LTI, estable y causal**, ya que su respuesta impulsional \( h(t) = u(t) - u(t - T) \) cumple las tres propiedades.
#
# ---
#
# </details>
#
# ---
#
# <details>
# <summary>📘 Problema 1.2 — Respuesta al impulso unidad</summary>
#
# **Enunciado:**
# Obtener la expresión analítica de la respuesta al impulso \( h(t) \) en función de \( T \).
#
# ---
#
# ### **Solución**
#
# Del apartado anterior:
# $$
# h(t) = u(t) - u(t - T)
# $$
#
# Representación gráfica: un **pulso rectangular** de amplitud 1 y duración \( T \):
# $$
# h(t) =
# \begin{cases}
# 1, & 0 \le t < T \\
# 0, & \text{en otro caso}
# \end{cases}
# $$
#
# ---
#
# **Teoría:**
# La respuesta al impulso de este sistema es una ventana rectangular.
# Actúa como un **filtro promediador** que acumula la energía de la señal durante un intervalo de longitud \( T \).
#
# ---
#
# </details>
#
# ---
#
# <details>
# <summary>📘 Problema 1.3 — Respuesta del sistema a una entrada escalón</summary>
#
# **Enunciado:**
# Suponiendo que el sistema es LTI, obtener y representar la salida a la señal de entrada:
# $$
# x_0(t) = u(t) - u(t - T)
# $$
#
# ---
#
# ### **Solución**
#
# Usamos la **convolución**:
# $$
# y_0(t) = x_0(t) * h(t) = \int_{-\infty}^{\infty} x_0(\tau)\, h(t - \tau)\, d\tau
# $$
#
# Sustituyendo \( x_0(t) = u(t) - u(t - T) \) y \( h(t) = u(t) - u(t - T) \):
#
# Por intervalos:
#
# $$
# y_0(t) =
# \begin{cases}
# 0, & t < 0 \\
# t, & 0 \le t < T \\
# 2T - t, & T \le t < 2T \\
# 0, & t \ge 2T
# \end{cases}
# $$
#
# ---
#
# **Teoría:**
# Esta salida es un **triángulo isósceles** de base \( 2T \).
# La convolución de dos pulsos rectangulares da una forma triangular.
# Este tipo de sistema se comporta como un **integrador finito o filtro suavizador**.
#
# ---
#
# </details>
#
# ---
#
# <details>
# <summary>📗 Problema 2.1 — Periodo fundamental y pulsación fundamental</summary>
#
# **Enunciado:**
# Dada la señal discreta
# $$
# x[n] = 1 + e^{j\pi n /3} + \tfrac{1}{2}\sin\!\left(\tfrac{\pi n}{2}\right) + \cos\!\left(\tfrac{3\pi n}{9}\right)
# $$
# calcular su **periodo fundamental \( N_0 \)** y su **pulsación fundamental \( \omega_0 \)**.
#
# ---
#
# ### **Solución paso a paso**
#
# Dividimos en tres componentes:
# - \( e^{j\pi n /3} \Rightarrow \omega_{01} = \pi/3 \Rightarrow N_{01} = 2\pi / (\pi/3) = 6 \)
# - \( \sin(\pi n/2) \Rightarrow \omega_{02} = \pi/2 \Rightarrow N_{02} = 2\pi / (\pi/2) = 4 \)
# - \( \cos(3\pi n/9) = \cos(\pi n/3) \Rightarrow \omega_{03} = \pi/3 \Rightarrow N_{03} = 6 \)
#
# El **periodo fundamental** es el **mínimo común múltiplo (m.c.m.)** de los periodos parciales:
# $$
# N_0 = \text{m.c.m.}(6,4,6) = 12
# $$
#
# y la **pulsación fundamental:**
# $$
# \omega_0 = \frac{2\pi}{N_0} = \frac{\pi}{6}
# $$
#
# ---
#
# **Teoría:**
# En señales discretas, la periodicidad depende de la **razón racional entre frecuencias**.
# Si las frecuencias son racionales en múltiplos de \( 2\pi \), la señal es periódica con \( N_0 = \text{m.c.m.}(N_i) \).
#
# ---
#
# </details>
#
# ---
#
# <details>
# <summary>📗 Problema 2.2 — Coeficientes de la DTFS</summary>
#
# **Enunciado:**
# Obtener los coeficientes \( a_k \) del **Desarrollo en Serie de Fourier Discreta (DTFS)** para la señal anterior.
#
# ---
#
# ### **Solución**
#
# Descomponemos:
# $$
# x[n] = 1 + e^{j(2\pi n /6)} + \tfrac{1}{2}\left( \frac{e^{j(3\pi n /6)} - e^{-j(3\pi n /6)}}{2j} \right)
# + \frac{e^{j(2\pi n /6)} + e^{-j(2\pi n /6)}}{2}
# $$
#
# De la expansión, los coeficientes no nulos son:
# $$
# a_0 = 1, \quad a_2 = 0.5, \quad a_3 = -\tfrac{j}{4}, \quad
# a_{-2} = 1.5, \quad a_{-3} = \tfrac{j}{4}
# $$
#
# ---
#
# **Teoría:**
# La DTFS representa una señal periódica discreta como:
# $$
# x[n] = \sum_{k=0}^{N_0-1} a_k e^{j k \omega_0 n}
# $$
# donde los \( a_k \) indican **amplitud y fase** de cada componente armónica.
#
# ---
#
# </details>
#
# ---
#
# <details>
# <summary>📗 Problema 2.3 — Propiedades de simetría y desplazamiento</summary>
#
# **Enunciado:**
# Si \( y[n] = x[-n - 2] \), hallar los coeficientes \( b_k \) de su DTFS y representarlos en módulo y fase.
#
# ---
#
# ### **Solución**
#
# Usamos propiedades de la DTFS:
#
# 1. **Desplazamiento en tiempo:**
#    \( x[n - n_0] \leftrightarrow a_k e^{-j k \omega_0 n_0} \)
# 2. **Inversión temporal:**
#    \( x[-n] \leftrightarrow a_{-k} \)
#
# Aplicamos ambos efectos:
#
# 1. Desplazamos \( n_0 = -2 \):
#    \( c_k = a_k e^{-2kj\pi/6} \)
# 2. Invertimos:
#    \( b_k = c_{-k} = a_{-k} e^{2kj\pi/6} \)
#
# ---
#
# **Teoría:**
# El desplazamiento temporal produce un **cambio de fase lineal** en el dominio de Fourier.
# La inversión en el tiempo refleja el espectro, intercambiando \( a_k \leftrightarrow a_{-k} \).
#
# ---
#
# </details>
#
# ---
#
# <details>
# <summary>📕 Problema 3.1 — Respuesta al impulso del sistema discreto</summary>
#
# **Enunciado:**
# Sistema definido por la ecuación:
# $$
# y[n] + y[n-2] = x[n] + x[n-1] + 2x[n-2]
# $$
# Obtener la **respuesta al impulso \( h_1[n] \)**.
#
# ---
#
# ### **Solución paso a paso**
#
# Sea \( x[n] = \delta[n] \):
#
# - \( h[0] = 1 \)
# - \( h[1] = 1 \)
# - \( h[2] = 2 + 1 = 3 \)
# - \( h[3] = h[1] = 1 \)
# - \( h[4] = h[2] = 3 \)
# - \( h[5] = h[3] = 1 \), etc.
#
# Por tanto:
# $$
# h_1[n] = \delta[n] + 2u[n-1] + (-1)^n u[n-1]
# $$
#
# ---
#
# **Teoría:**
# Este sistema es **recursivo de segundo orden** (depende de salidas pasadas).
# Su respuesta impulsional oscila alternando valores 1 y 3 debido al término \( y[n-2] \).
#
# ---
#
# </details>
#
# ---
#
# <details>
# <summary>📕 Problema 3.2 — Salida ante un pulso rectangular</summary>
#
# **Enunciado:**
# Calcular la salida \( y_1[n] \) cuando
# $$
# x[n] = u[n+1] - u[n-2]
# $$
#
# ---
#
# ### **Solución**
#
# La señal de entrada es un **pulso rectangular** de 3 muestras de ancho y amplitud 1.
# La salida es la **convolución**:
# $$
# y_1[n] = x[n] * h_1[n]
# $$
#
# Gráficamente equivale a sumar tres muestras consecutivas de \( h_1[n] \).
# Formalmente:
# $$
# y_1[n] = \delta[n-1] + 2\delta[n] + 5\delta[n-1] + 6u[n-2] + (-1)^{n+1}u[n-2]
# $$
#
# ---
#
# **Teoría:**
# Convolucionar un pulso con una respuesta periódica suaviza la señal y genera una suma local.
# El resultado tiene un **transitorio inicial** y luego una oscilación periódica.
#
# ---
#
# </details>
#
# ---
#
# <details>
# <summary>📕 Problema 3.3 — Sistema paralelo</summary>
#
# **Enunciado:**
# Se conecta el sistema anterior en paralelo con otro cuya respuesta es \( h_2[n] = 2\delta[n] \).
# Obtener la salida total \( y[n] \).
#
# ---
#
# ### **Solución**
#
# En paralelo, la salida total es la suma de las salidas individuales:
# $$
# y[n] = y_1[n] + 2x[n]
# $$
#
# Sustituyendo:
# $$
# y[n] = 3\delta[n-1] + 4\delta[n] + 5u[n-1] + (-1)^{n+1}u[n-1]
# $$
#
# ---
#
# **Teoría:**
# La conexión **paralela** de sistemas LTI equivale a sumar sus **respuestas al impulso**.
# El sistema resultante hereda la **causalidad** y **estabilidad** si ambas se cumplen.
#
# ---
#
# </details>
#
# ---
#
# **Resumen general:**
# - Los tres problemas del examen integran los **bloques principales del temario**:
#   - **Tema 1:** señales y energía (definición de $h(t)$ y convolución).
#   - **Tema 2:** propiedades y respuesta de sistemas LTI (causalidad, estabilidad).
#   - **Tema 3:** análisis espectral y DTFS (frecuencia fundamental, coeficientes, simetrías).
#
# ---

# %% [markdown]
# ## Examen 1 - Señales y Sistemas (Teoría 2023)
#
# ---
#
# <details>
# <summary>Problema 1.1 — Propiedades del sistema continuo</summary>
#
# **Enunciado**
# Sea el sistema de tiempo continuo definido por
# $$
# y(t)=\int_{t-T}^{t} x(\tau)\,d\tau,\qquad T\in\mathbb{R}^+,\, T<\infty.
# $$
# Analizar si el sistema presenta **estabilidad**, **invarianza en el tiempo** y **causalidad**.
#
# ---
#
# ### 1) Estabilidad
# Si la entrada está acotada, $|x(t)|\le B$ para todo $t$, entonces
# $$
# |y(t)|=\left|\int_{t-T}^{t}x(\tau)\,d\tau\right|
# \le \int_{t-T}^{t}|x(\tau)|\,d\tau
# \le B\int_{t-T}^{t} d\tau
# = BT < \infty.
# $$
# **Conclusión:** BIBO **estable**.
#
# ---
#
# ### 2) Invarianza temporal
# Para $x'(t)=x(t-t_0)$,
# $$
# y'(t)=\int_{t-T}^{t}x'(\tau)\,d\tau
# =\int_{t-T}^{t}x(\tau-t_0)\,d\tau
# =\int_{t-T-t_0}^{t-t_0}x(\sigma)\,d\sigma
# = y(t-t_0).
# $$
# **Conclusión:** **invariante en el tiempo**.
#
# ---
#
# ### 3) Causalidad
# Tomando $x(t)=\delta(t)$,
# $$
# h(t)=\int_{t-T}^{t}\delta(\tau)\,d\tau
# =u(t)-u(t-T),
# $$
# y como $h(t)=0$ para $t<0$, el sistema es **causal**.
#
# ---
#
# **Teoría**
# El operador integra la entrada en una **ventana de duración $T$** (filtro promediador). La respuesta impulsional es $h(t)=u(t)-u(t-T)$.
# </details>
#
# ---
#
# <details>
# <summary>Problema 1.2 — Respuesta al impulso unidad</summary>
#
# **Enunciado**
# Obtener la expresión analítica de la respuesta al impulso $h(t)$ en función de $T$.
#
# **Solución**
# $$
# h(t)=u(t)-u(t-T)=
# \begin{cases}
# 1,& 0\le t<T,\\[2mm]
# 0,& \text{en otro caso.}
# \end{cases}
# $$
#
# **Teoría**
# $h(t)$ es un **pulso rectangular** de amplitud 1 y anchura $T$.
# </details>
#
# ---
#
# <details>
# <summary>Problema 1.3 — Salida ante $x_0(t)=u(t)-u(t-T)$</summary>
#
# **Enunciado**
# Calcular y representar $y_0(t)=x_0(t)*h(t)$.
#
# **Solución**
# $$
# y_0(t)=\int_{-\infty}^{\infty}x_0(\tau)\,h(t-\tau)\,d\tau
# \Rightarrow
# y_0(t)=
# \begin{cases}
# 0,& t<0,\\
# t,& 0\le t<T,\\
# 2T-t,& T\le t<2T,\\
# 0,& t\ge 2T.
# \end{cases}
# $$
#
# **Teoría**
# La convolución de dos rectángulos da un **triángulo** de base $2T$.
# </details>
#
# ---
#
# <details>
# <summary>Problema 2.1 — Periodo y pulsación fundamentales (DT)</summary>
#
# **Enunciado**
# Para
# $$
# x[n]=1+e^{j\pi n/3}+\tfrac12\sin\!\left(\tfrac{\pi n}{2}\right)+\cos\!\left(\tfrac{3\pi n}{9}\right),
# $$
# calcular $N_0$ y $\omega_0$.
#
# **Solución**
# $\omega=\{\pi/3,\ \pi/2,\ \pi/3\}\Rightarrow N=\{6,\ 4,\ 6\}$
# $$
# N_0=\operatorname{mcm}(6,4,6)=12,\qquad \omega_0=\frac{2\pi}{N_0}=\frac{\pi}{6}.
# $$
#
# **Teoría**
# En tiempo discreto, la señal es periódica si todas las frecuencias son **racionales** en múltiplos de $2\pi$; $N_0$ es la m.c.m. de los periodos parciales.
# </details>
#
# ---
#
# <details>
# <summary>Problema 2.2 — Coeficientes de la DTFS</summary>
#
# **Enunciado**
# Obtener los coeficientes $a_k$ de la DTFS de $x[n]$ del problema anterior.
#
# **Solución**
# Reescribiendo en exponenciales:
# $$
# x[n]=1+e^{j(2\pi n/6)}+\tfrac12\frac{e^{j(3\pi n/6)}-e^{-j(3\pi n/6)}}{2j}
# +\frac{e^{j(2\pi n/6)}+e^{-j(2\pi n/6)}}{2}.
# $$
# Coeficientes no nulos (indexados con $N_0=12$, $\omega_0=\pi/6$):
# $$
# a_0=1,\quad a_2=\tfrac12,\quad a_3=-\tfrac{j}{4},\quad a_{-2}=\tfrac32,\quad a_{-3}=\tfrac{j}{4}.
# $$
#
# **Teoría**
# $$
# x[n]=\sum_{k=0}^{N_0-1} a_k e^{jk\omega_0 n}.
# $$
# $a_k$ codifican **módulo** y **fase** de cada armónico.
# </details>
#
# ---
#
# <details>
# <summary>Problema 2.3 — Efectos de inversión y desplazamiento</summary>
#
# **Enunciado**
# Si $y[n]=x[-n-2]$, hallar los coeficientes $b_k$ de su DTFS.
#
# **Solución**
# Propiedades:
# - Desplazamiento $x[n-n_0]\ \leftrightarrow\ a_k e^{-jk\omega_0 n_0}$.
# - Inversión $x[-n]\ \leftrightarrow\ a_{-k}$.
#
# Aplicando a $y[n]=x[-(n+2)]$:
# $$
# b_k=a_{-k}\,e^{+jk\omega_0\cdot 2}
# =a_{-k}\,e^{j k\pi/3}.
# $$
#
# **Teoría**
# El desplazamiento temporal introduce **fase lineal**; la inversión **refleja** el espectro ($k\leftrightarrow -k$).
# </details>
#
# ---
#
# <details>
# <summary>Problema 3.1 — Respuesta al impulso de un sistema DT</summary>
#
# **Enunciado**
# $$
# y[n]+y[n-2]=x[n]+x[n-1]+2x[n-2].
# $$
# Obtener $h_1[n]$.
#
# **Solución**
# Con $x[n]=\delta[n]$ y condiciones causales:
# \[
# \begin{aligned}
# h[0]&=1,\\
# h[1]&=1,\\
# h[2]&=3,\\
# h[3]&=1,\\
# h[4]&=3,\ \ldots
# \end{aligned}
# \]
# Forma cerrada (según la descomposición dada en el examen):
# $$
# h_1[n]=\delta[n]+2\,u[n-1]+(-1)^n u[n-1].
# $$
#
# **Teoría**
# Ecuación en diferencias de 2º orden; la parte oscilatoria proviene del término $y[n-2]$.
# </details>
#
# ---
#
# <details>
# <summary>Problema 3.2 — Salida para un pulso de 3 muestras</summary>
#
# **Enunciado**
# $x[n]=u[n+1]-u[n-2]$. Calcular $y_1[n]=x[n]*h_1[n]$.
#
# **Solución (expresión dada en la resolución del examen)**
# $$
# y_1[n]=\delta[n-1]+2\delta[n]+5\delta[n-1]+6u[n-2]+(-1)^{n+1}u[n-2].
# $$
#
# **Teoría**
# Convolucionar un pulso con $h_1[n]$ suma copias desplazadas de la respuesta impulsional.
# </details>
#
# ---
#
# <details>
# <summary>Problema 3.3 — Conexión en paralelo</summary>
#
# **Enunciado**
# Se añade en paralelo $h_2[n]=2\delta[n]$. Hallar la salida total $y[n]$ para la misma entrada.
#
# **Solución**
# $$
# y[n]=y_1[n]+2x[n]
# =3\delta[n-1]+4\delta[n]+5u[n-1]+(-1)^{n+1}u[n-1].
# $$
#
# **Teoría**
# En paralelo, las respuestas al impulso **se suman**; se preservan causalidad y estabilidad si cada rama las cumple.
# </details>
#
# ---
